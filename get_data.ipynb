# %%
import requests
from datetime import datetime
from pprint import pprint

import pandas as pd

# %%
def get_data_by_api(url):

    params = {
        'game': 'aoe2de', 
        'leaderboard_id': '3', 
        'start':'1',
        'count':'100'
    }

    response = requests.get(
        url, 
        params=params, 
    )

    if response.status_code == 200:
        data = response.json()
    else:
        print('Chyba při získávání dat')
    
    return data
# Out:
# {'total': 47879,
#  'leaderboard_id': 3,
#  'start': 1,
#  'count': 100,
#  'leaderboard': [{'profile_id': 199325,
#    'rank': 1,
#    'rating': 2813,
#    'steam_id': '76561198449406083',
#    'icon': None,
#    'name': '[aM] Hera',
#    'clan': None,
#    'country': 'CA',
#    'previous_rating': 2802,
#    'highest_rating': 2838,
#    'streak': 1,
#    'lowest_streak': -6,
#    'highest_streak': 36,
#    'games': 3615,
#    'wins': 2554,
#    'losses': 1061,
#    'drops': 30,
#    'last_match_time': 1682178714},
#   {'profile_id': 196240,
#    'rank': 2,
#    'rating': 2780,
#    'steam_id': '76561197984749679',
#    'icon': None,
#    'name': 'GL.TheViper',
#    'clan': None,
#    'country': 'NO',
#    'previous_rating': 2779,
#    'highest_rating': 2813,
#    'streak': 5,
#    'lowest_streak': -9,
#    'highest_streak': 22,
#    'games': 1618,
#    'wins': 1067,
#    'losses': 551,
#    'drops': 4,
#    'last_match_time': 1682202659},
#   {'profile_id': 208393,
#    'rank': 3,
#    'rating': 2718,
#    'steam_id': '76561198027378107',
#    'icon': None,
#    'name': '[aM] Nicov',
#    'clan': None,
#    'country': 'AR',
#    'previous_rating': 2707,
#    'highest_rating': 2730,
#    'streak': 4,
#    'lowest_streak': -5,
#    'highest_streak': 22,
#    'games': 1514,
#    'wins': 1098,
#    'losses': 416,
#    'drops': 8,
#    'last_match_time': 1682049949},
#   {'profile_id': 2644601,
#    'rank': 4,
#    'rating': 2694,
#    'steam_id': '76561199057707367',
#    'icon': None,
#    'name': '__TheMbL__',
#    'clan': None,
#    'country': 'NO',
#    'previous_rating': 2686,
#    'highest_rating': 2694,
#    'streak': 6,
#    'lowest_streak': -5,
#    'highest_streak': 39,
#    'games': 1020,
#    'wins': 768,
#    'losses': 252,
#    'drops': 9,
#    'last_match_time': 1681137456},
#   {'profile_id': 1862892,
#    'rank': 5,
#    'rating': 2688,
#    'steam_id': '76561199032160044',
#    'icon': None,
#    'name': 'Modri',
#    'clan': None,
#    'country': 'SI',
#    'previous_rating': 2673,
#    'highest_rating': 2688,
#    'streak': 8,
#    'lowest_streak': -6,
#    'highest_streak': 24,
#    'games': 677,
#    'wins': 420,
#    'losses': 257,
#    'drops': 2,
#    'last_match_time': 1682178569},
#   {'profile_id': 251265,
#    'rank': 6,
#    'rating': 2671,
#    'steam_id': '76561197996386232',
#    'icon': None,
#    'name': '[aM]MbL40C',
#    'clan': None,
#    'country': 'NO',
#    'previous_rating': 2661,
#    'highest_rating': 2751,
#    'streak': 12,
#    'lowest_streak': -9,
#    'highest_streak': 23,
#    'games': 4341,
#    'wins': 3019,
#    'losses': 1322,
#    'drops': 96,
#    'last_match_time': 1682260014},
#   {'profile_id': 197964,
#    'rank': 7,
#    'rating': 2669,
#    'steam_id': '76561198179087382',
#    'icon': None,
#    'name': 'Yo',
#    'clan': 'WWP',
#    'country': 'CN',
#    'previous_rating': 2680,
#    'highest_rating': 2799,
#    'streak': -1,
#    'lowest_streak': -7,
#    'highest_streak': 15,
#    'games': 2302,
#    'wins': 1459,
#    'losses': 843,
#    'drops': 22,
#    'last_match_time': 1682178714},
#   {'profile_id': 4422938,
#    'rank': 8,
#    'rating': 2660,
#    'steam_id': '76561199118807671',
#    'icon': None,
#    'name': '___MbL___',
#    'clan': None,
#    'country': 'NO',
#    'previous_rating': 2648,
#    'highest_rating': 2676,
#    'streak': 1,
#    'lowest_streak': -10,
#    'highest_streak': 73,
#    'games': 513,
#    'wins': 394,
#    'losses': 119,
#    'drops': 4,
#    'last_match_time': 1681560208},
#   {'profile_id': 9473909,
#    'rank': 9,
#    'rating': 2656,
#    'steam_id': '76561199240324201',
#    'icon': None,
#    'name': 'Kalashnicov',
#    'clan': None,
#    'country': 'AR',
#    'previous_rating': 2716,
#    'highest_rating': 2716,
#    'streak': 2,
#    'lowest_streak': -7,
#    'highest_streak': 60,
#    'games': 523,
#    'wins': 366,
#    'losses': 157,
#    'drops': 5,
#    'last_match_time': 1680919031},
#   {'profile_id': 271202,
#    'rank': 10,
#    'rating': 2648,
#    'steam_id': '76561198000635167',
#    'icon': None,
#    'name': 'SalzZ_Vinchester',
#    'clan': None,
#    'country': 'RU',
#    'previous_rating': 2645,
#    'highest_rating': 2742,
#    'streak': 7,
#    'lowest_streak': -6,
#    'highest_streak': 18,
#    'games': 1479,
#    'wins': 1024,
#    'losses': 455,
#    'drops': 7,
#    'last_match_time': 1682071967},
#   {'profile_id': 199170,
#    'rank': 11,
#    'rating': 2639,
#    'steam_id': '76561197992981071',
#    'icon': None,
#    'name': 'CDUB.dogao',
#    'clan': None,
#    'country': 'BR',
#    'previous_rating': 2635,
#    'highest_rating': 2642,
#    'streak': 4,
#    'lowest_streak': -5,
#    'highest_streak': 32,
#    'games': 1735,
#    'wins': 1289,
#    'losses': 446,
#    'drops': 17,
#    'last_match_time': 1681318351},
#   {'profile_id': 212721,
#    'rank': 12,
#    'rating': 2637,
#    'steam_id': '76561198116921964',
#    'icon': None,
#    'name': 'mYi.Sitaux',
#    'clan': 'FrCo',
#    'country': 'FR',
#    'previous_rating': 2621,
#    'highest_rating': 2711,
#    'streak': 5,
#    'lowest_streak': -5,
#    'highest_streak': 29,
#    'games': 1126,
#    'wins': 775,
#    'losses': 351,
#    'drops': 6,
#    'last_match_time': 1681866817},
#   {'profile_id': 4351237,
#    'rank': 13,
#    'rating': 2634,
#    'steam_id': '76561199114437308',
#    'icon': None,
#    'name': 'mYi.Sitaux',
#    'clan': 'FrCo',
#    'country': 'FR',
#    'previous_rating': 2619,
#    'highest_rating': 2634,
#    'streak': 8,
#    'lowest_streak': -4,
#    'highest_streak': 40,
#    'games': 316,
#    'wins': 240,
#    'losses': 76,
#    'drops': 1,
#    'last_match_time': 1681527389},
#   {'profile_id': 666976,
#    'rank': 14,
#    'rating': 2630,
#    'steam_id': '76561198275359848',
#    'icon': None,
#    'name': '_Barles_',
#    'clan': None,
#    'country': 'PL',
#    'previous_rating': 2645,
#    'highest_rating': 2697,
#    'streak': -2,
#    'lowest_streak': -7,
#    'highest_streak': 12,
#    'games': 2634,
#    'wins': 1659,
#    'losses': 975,
#    'drops': 12,
#    'last_match_time': 1682178569},
#   {'profile_id': 582058,
#    'rank': 15,
#    'rating': 2622,
#    'steam_id': '76561198032611326',
#    'icon': None,
#    'name': '[aM] Hearttt',
#    'clan': None,
#    'country': 'PE',
#    'previous_rating': 2608,
#    'highest_rating': 2732,
#    'streak': 1,
#    'lowest_streak': -7,
#    'highest_streak': 14,
#    'games': 2448,
#    'wins': 1503,
#    'losses': 945,
#    'drops': 20,
#    'last_match_time': 1682228436},
#   {'profile_id': 3209724,
#    'rank': 16,
#    'rating': 2612,
#    'steam_id': '76561198410119452',
#    'icon': None,
#    'name': 'Arabia Player',
#    'clan': None,
#    'country': 'CA',
#    'previous_rating': 2626,
#    'highest_rating': 2626,
#    'streak': -1,
#    'lowest_streak': -3,
#    'highest_streak': 45,
#    'games': 250,
#    'wins': 197,
#    'losses': 53,
#    'drops': 0,
#    'last_match_time': 1682123008},
#   {'profile_id': 506898,
#    'rank': 17,
#    'rating': 2593,
#    'steam_id': '76561198362219694',
#    'icon': None,
#    'name': '[aM] Liereyy',
#    'clan': None,
#    'country': 'AT',
#    'previous_rating': 2612,
#    'highest_rating': 2659,
#    'streak': -1,
#    'lowest_streak': -6,
#    'highest_streak': 16,
#    'games': 1039,
#    'wins': 699,
#    'losses': 340,
#    'drops': 9,
#    'last_match_time': 1682167488},
#   {'profile_id': 1486575,
#    'rank': 18,
#    'rating': 2586,
#    'steam_id': '76561199021127843',
#    'icon': None,
#    'name': 'CDUB.doguinhoCaRaMeLo_xD_br_2k',
#    'clan': None,
#    'country': 'BR',
#    'previous_rating': 2598,
#    'highest_rating': 2632,
#    'streak': -1,
#    'lowest_streak': -6,
#    'highest_streak': 20,
#    'games': 1500,
#    'wins': 1085,
#    'losses': 415,
#    'drops': 6,
#    'last_match_time': 1682136233},
#   {'profile_id': 579679,
#    'rank': 19,
#    'rating': 2579,
#    'steam_id': '76561198425688505',
#    'icon': None,
#    'name': 'Fox.Margougou',
#    'clan': 'SINGE',
#    'country': 'FR',
#    'previous_rating': 2560,
#    'highest_rating': 2579,
#    'streak': 5,
#    'lowest_streak': -7,
#    'highest_streak': 12,
#    'games': 1710,
#    'wins': 964,
#    'losses': 746,
#    'drops': 16,
#    'last_match_time': 1682215382},
#   {'profile_id': 614315,
#    'rank': 20,
#    'rating': 2552,
#    'steam_id': '76561198135964589',
#    'icon': None,
#    'name': 'slam',
#    'clan': None,
#    'country': 'CA',
#    'previous_rating': 2566,
#    'highest_rating': 2579,
#    'streak': -1,
#    'lowest_streak': -8,
#    'highest_streak': 14,
#    'games': 3589,
#    'wins': 2150,
#    'losses': 1439,
#    'drops': 17,
#    'last_match_time': 1682228436},
#   {'profile_id': 208611,
#    'rank': 21,
#    'rating': 2552,
#    'steam_id': '76561198325239137',
#    'icon': None,
#    'name': 'Villese',
#    'clan': None,
#    'country': 'FI',
#    'previous_rating': 2577,
#    'highest_rating': 2740,
#    'streak': -2,
#    'lowest_streak': -7,
#    'highest_streak': 19,
#    'games': 2832,
#    'wins': 1856,
#    'losses': 976,
#    'drops': 13,
#    'last_match_time': 1682257827},
#   {'profile_id': 4620061,
#    'rank': 22,
#    'rating': 2540,
#    'steam_id': '76561199124381546',
#    'icon': None,
#    'name': 'Phantom',
#    'clan': None,
#    'country': 'DE',
#    'previous_rating': 2521,
#    'highest_rating': 2623,
#    'streak': 2,
#    'lowest_streak': -6,
#    'highest_streak': 27,
#    'games': 1953,
#    'wins': 1194,
#    'losses': 759,
#    'drops': 8,
#    'last_match_time': 1682174366},
#   {'profile_id': 11406458,
#    'rank': 23,
#    'rating': 2532,
#    'steam_id': '76561199406815843',
#    'icon': None,
#    'name': '肥宝宝',
#    'clan': None,
#    'country': 'CN',
#    'previous_rating': 2546,
#    'highest_rating': 2659,
#    'streak': -1,
#    'lowest_streak': -4,
#    'highest_streak': 12,
#    'games': 305,
#    'wins': 216,
#    'losses': 89,
#    'drops': 1,
#    'last_match_time': 1682105645},
#   {'profile_id': 197388,
#    'rank': 24,
#    'rating': 2523,
#    'steam_id': '76561198088251629',
#    'icon': None,
#    'name': 'GL.TaToH',
#    'clan': 'TaToH',
#    'country': 'ES',
#    'previous_rating': 2511,
#    'highest_rating': 2605,
#    'streak': 13,
#    'lowest_streak': -6,
#    'highest_streak': 32,
#    'games': 856,
#    'wins': 617,
#    'losses': 239,
#    'drops': 4,
#    'last_match_time': 1681750983},
#   {'profile_id': 347269,
#    'rank': 25,
#    'rating': 2523,
#    'steam_id': '76561198364718180',
#    'icon': None,
#    'name': 'Gamdom.ACCM | AOEBuilds.com',
#    'clan': None,
#    'country': 'VN',
#    'previous_rating': 2536,
#    'highest_rating': 2668,
#    'streak': 1,
#    'lowest_streak': -7,
#    'highest_streak': 25,
#    'games': 3337,
#    'wins': 2307,
#    'losses': 1030,
#    'drops': 43,
#    'last_match_time': 1682052909},
#   {'profile_id': 256338,
#    'rank': 26,
#    'rating': 2522,
#    'steam_id': '76561198007187809',
#    'icon': None,
#    'name': 'Running',
#    'clan': None,
#    'country': 'DE',
#    'previous_rating': 2541,
#    'highest_rating': 2560,
#    'streak': -2,
#    'lowest_streak': -8,
#    'highest_streak': 13,
#    'games': 2948,
#    'wins': 1689,
#    'losses': 1259,
#    'drops': 20,
#    'last_match_time': 1682258474},
#   {'profile_id': 1754629,
#    'rank': 27,
#    'rating': 2522,
#    'steam_id': '76561198807828662',
#    'icon': None,
#    'name': 'SalzZ_classicpro',
#    'clan': None,
#    'country': 'UA',
#    'previous_rating': 2512,
#    'highest_rating': 2541,
#    'streak': 2,
#    'lowest_streak': -8,
#    'highest_streak': 22,
#    'games': 1692,
#    'wins': 1055,
#    'losses': 637,
#    'drops': 11,
#    'last_match_time': 1681646797},
#   {'profile_id': 2368761,
#    'rank': 28,
#    'rating': 2521,
#    'steam_id': '76561199047138712',
#    'icon': None,
#    'name': 'Fox.Margougou',
#    'clan': 'FrCo',
#    'country': 'FR',
#    'previous_rating': 2502,
#    'highest_rating': 2574,
#    'streak': 1,
#    'lowest_streak': -7,
#    'highest_streak': 16,
#    'games': 1164,
#    'wins': 674,
#    'losses': 490,
#    'drops': 13,
#    'last_match_time': 1682179311},
#   {'profile_id': 2783660,
#    'rank': 29,
#    'rating': 2515,
#    'steam_id': '76561199062883266',
#    'icon': None,
#    'name': 'DS_Sebastian',
#    'clan': 'Biry',
#    'country': 'UY',
#    'previous_rating': 2496,
#    'highest_rating': 2603,
#    'streak': 4,
#    'lowest_streak': -7,
#    'highest_streak': 12,
#    'games': 2063,
#    'wins': 1134,
#    'losses': 929,
#    'drops': 23,
#    'last_match_time': 1682203365},
#   {'profile_id': 196310,
#    'rank': 30,
#    'rating': 2514,
#    'steam_id': '76561198275970890',
#    'icon': None,
#    'name': '[KGB] F1Re',
#    'clan': '1KGB1',
#    'country': 'BR',
#    'previous_rating': 2508,
#    'highest_rating': 2551,
#    'streak': 5,
#    'lowest_streak': -9,
#    'highest_streak': 28,
#    'games': 3558,
#    'wins': 2454,
#    'losses': 1104,
#    'drops': 29,
#    'last_match_time': 1682039647},
#   {'profile_id': 628503,
#    'rank': 31,
#    'rating': 2510,
#    'steam_id': '76561198036586732',
#    'icon': None,
#    'name': 'Valas',
#    'clan': None,
#    'country': 'FI',
#    'previous_rating': 2494,
#    'highest_rating': 2645,
#    'streak': 1,
#    'lowest_streak': -7,
#    'highest_streak': 16,
#    'games': 1982,
#    'wins': 1153,
#    'losses': 829,
#    'drops': 2,
#    'last_match_time': 1682167392},
#   {'profile_id': 1966276,
#    'rank': 32,
#    'rating': 2500,
#    'steam_id': '76561198376755697',
#    'icon': None,
#    'name': 'MING',
#    'clan': 'WWP',
#    'country': 'HK',
#    'previous_rating': 2483,
#    'highest_rating': 2505,
#    'streak': 3,
#    'lowest_streak': -7,
#    'highest_streak': 12,
#    'games': 1387,
#    'wins': 790,
#    'losses': 597,
#    'drops': 6,
#    'last_match_time': 1681443893},
#   {'profile_id': 1407942,
#    'rank': 33,
#    'rating': 2500,
#    'steam_id': '76561198121306763',
#    'icon': None,
#    'name': '3D!Dark',
#    'clan': None,
#    'country': 'RU',
#    'previous_rating': 2482,
#    'highest_rating': 2500,
#    'streak': 1,
#    'lowest_streak': -11,
#    'highest_streak': 9,
#    'games': 2972,
#    'wins': 1530,
#    'losses': 1442,
#    'drops': 18,
#    'last_match_time': 1682009300},
#   {'profile_id': 265517,
#    'rank': 34,
#    'rating': 2493,
#    'steam_id': '76561198198305605',
#    'icon': None,
#    'name': 'mYi.Daniel',
#    'clan': None,
#    'country': 'US',
#    'previous_rating': 2483,
#    'highest_rating': 2653,
#    'streak': 1,
#    'lowest_streak': -11,
#    'highest_streak': 10,
#    'games': 2601,
#    'wins': 1353,
#    'losses': 1248,
#    'drops': 13,
#    'last_match_time': 1682255634},
#   {'profile_id': 357795,
#    'rank': 35,
#    'rating': 2488,
#    'steam_id': '76561198367209710',
#    'icon': None,
#    'name': 'CL.DracKeN',
#    'clan': 'C1own',
#    'country': 'CZ',
#    'previous_rating': 2474,
#    'highest_rating': 2588,
#    'streak': 1,
#    'lowest_streak': -13,
#    'highest_streak': 15,
#    'games': 7415,
#    'wins': 4174,
#    'losses': 3241,
#    'drops': 64,
#    'last_match_time': 1682261776},
#   {'profile_id': 409748,
#    'rank': 36,
#    'rating': 2484,
#    'steam_id': '76561198099659716',
#    'icon': None,
#    'name': 'Capoch',
#    'clan': None,
#    'country': 'AR',
#    'previous_rating': 2455,
#    'highest_rating': 2576,
#    'streak': 3,
#    'lowest_streak': -6,
#    'highest_streak': 13,
#    'games': 1504,
#    'wins': 905,
#    'losses': 599,
#    'drops': 13,
#    'last_match_time': 1681847535},
#   {'profile_id': 182749,
#    'rank': 37,
#    'rating': 2478,
#    'steam_id': '76561198131139989',
#    'icon': None,
#    'name': 'The_Dragonstar',
#    'clan': None,
#    'country': 'IN',
#    'previous_rating': 2459,
#    'highest_rating': 2502,
#    'streak': 2,
#    'lowest_streak': -9,
#    'highest_streak': 15,
#    'games': 2290,
#    'wins': 1378,
#    'losses': 912,
#    'drops': 45,
#    'last_match_time': 1681743109},
#   {'profile_id': 2776293,
#    'rank': 38,
#    'rating': 2476,
#    'steam_id': '76561199063069362',
#    'icon': None,
#    'name': 'Combi | KingstoNe',
#    'clan': 'Combi',
#    'country': 'MX',
#    'previous_rating': 2493,
#    'highest_rating': 2560,
#    'streak': -2,
#    'lowest_streak': -6,
#    'highest_streak': 14,
#    'games': 2133,
#    'wins': 1175,
#    'losses': 958,
#    'drops': 14,
#    'last_match_time': 1682190751},
#   {'profile_id': 572017,
#    'rank': 39,
#    'rating': 2472,
#    'steam_id': '76561198426853065',
#    'icon': None,
#    'name': 'TheMax',
#    'clan': None,
#    'country': 'FI',
#    'previous_rating': 2482,
#    'highest_rating': 2537,
#    'streak': -1,
#    'lowest_streak': -6,
#    'highest_streak': 20,
#    'games': 1026,
#    'wins': 683,
#    'losses': 343,
#    'drops': 1,
#    'last_match_time': 1682085710},
#   {'profile_id': 198035,
#    'rank': 40,
#    'rating': 2454,
#    'steam_id': '76561198044559189',
#    'icon': None,
#    'name': 'GL.DauT',
#    'clan': 'DauT',
#    'country': 'RS',
#    'previous_rating': 2444,
#    'highest_rating': 2576,
#    'streak': 2,
#    'lowest_streak': -9,
#    'highest_streak': 30,
#    'games': 2189,
#    'wins': 1276,
#    'losses': 913,
#    'drops': 15,
#    'last_match_time': 1682179088},
#   {'profile_id': 2090225,
#    'rank': 41,
#    'rating': 2452,
#    'steam_id': '76561198242526658',
#    'icon': None,
#    'name': 'miguel',
#    'clan': None,
#    'country': 'BR',
#    'previous_rating': 2439,
#    'highest_rating': 2557,
#    'streak': 1,
#    'lowest_streak': -10,
#    'highest_streak': 22,
#    'games': 2356,
#    'wins': 1343,
#    'losses': 1013,
#    'drops': 12,
#    'last_match_time': 1682085816},
#   {'profile_id': 229071,
#    'rank': 42,
#    'rating': 2451,
#    'steam_id': '76561198217460091',
#    'icon': None,
#    'name': 'Combi | Uzzi',
#    'clan': 'Combi',
#    'country': 'MX',
#    'previous_rating': 2438,
#    'highest_rating': 2481,
#    'streak': 1,
#    'lowest_streak': -8,
#    'highest_streak': 20,
#    'games': 2915,
#    'wins': 1494,
#    'losses': 1421,
#    'drops': 30,
#    'last_match_time': 1682095466},
#   {'profile_id': 728551,
#    'rank': 43,
#    'rating': 2445,
#    'steam_id': '76561198355342951',
#    'icon': None,
#    'name': 'RiskyDice',
#    'clan': 'Biry',
#    'country': 'JP',
#    'previous_rating': 2429,
#    'highest_rating': 2445,
#    'streak': 3,
#    'lowest_streak': -7,
#    'highest_streak': 12,
#    'games': 836,
#    'wins': 514,
#    'losses': 322,
#    'drops': 9,
#    'last_match_time': 1681489853},
#   {'profile_id': 452924,
#    'rank': 44,
#    'rating': 2441,
#    'steam_id': '76561198033713695',
#    'icon': None,
#    'name': 'JackK',
#    'clan': None,
#    'country': 'PL',
#    'previous_rating': 2431,
#    'highest_rating': 2473,
#    'streak': 2,
#    'lowest_streak': -9,
#    'highest_streak': 12,
#    'games': 1483,
#    'wins': 839,
#    'losses': 644,
#    'drops': 31,
#    'last_match_time': 1681679043},
#   {'profile_id': 3230529,
#    'rank': 45,
#    'rating': 2428,
#    'steam_id': '76561198098401046',
#    'icon': None,
#    'name': 'IamChris',
#    'clan': None,
#    'country': 'CA',
#    'previous_rating': 2444,
#    'highest_rating': 2444,
#    'streak': -1,
#    'lowest_streak': -13,
#    'highest_streak': 24,
#    'games': 1147,
#    'wins': 687,
#    'losses': 460,
#    'drops': 9,
#    'last_match_time': 1682223597},
#   {'profile_id': 419803,
#    'rank': 46,
#    'rating': 2428,
#    'steam_id': '76561198419918984',
#    'icon': None,
#    'name': 'saymyname',
#    'clan': None,
#    'country': 'VN',
#    'previous_rating': 2426,
#    'highest_rating': 2498,
#    'streak': 1,
#    'lowest_streak': -7,
#    'highest_streak': 16,
#    'games': 3159,
#    'wins': 2026,
#    'losses': 1133,
#    'drops': 66,
#    'last_match_time': 1681900265},
#   {'profile_id': 14665996,
#    'rank': 47,
#    'rating': 2427,
#    'steam_id': '76561199153076089',
#    'icon': None,
#    'name': 'GG',
#    'clan': None,
#    'country': 'UA',
#    'previous_rating': 2410,
#    'highest_rating': 2427,
#    'streak': 18,
#    'lowest_streak': -1,
#    'highest_streak': 38,
#    'games': 76,
#    'wins': 73,
#    'losses': 3,
#    'drops': 1,
#    'last_match_time': 1682258251},
#   {'profile_id': 254415,
#    'rank': 48,
#    'rating': 2425,
#    'steam_id': '76561198011417995',
#    'icon': None,
#    'name': 'Modri',
#    'clan': None,
#    'country': 'SI',
#    'previous_rating': 2410,
#    'highest_rating': 2561,
#    'streak': 1,
#    'lowest_streak': -8,
#    'highest_streak': 12,
#    'games': 1015,
#    'wins': 627,
#    'losses': 388,
#    'drops': 9,
#    'last_match_time': 1682263802},
#   {'profile_id': 239238,
#    'rank': 49,
#    'rating': 2418,
#    'steam_id': '76561198113285862',
#    'icon': None,
#    'name': 'Fedex',
#    'clan': None,
#    'country': 'AR',
#    'previous_rating': 2399,
#    'highest_rating': 2418,
#    'streak': 3,
#    'lowest_streak': -7,
#    'highest_streak': 16,
#    'games': 733,
#    'wins': 427,
#    'losses': 306,
#    'drops': 7,
#    'last_match_time': 1681739711},
#   {'profile_id': 2821727,
#    'rank': 50,
#    'rating': 2418,
#    'steam_id': '76561199031392883',
#    'icon': None,
#    'name': 'Fish',
#    'clan': None,
#    'country': 'VN',
#    'previous_rating': 2436,
#    'highest_rating': 2484,
#    'streak': -2,
#    'lowest_streak': -8,
#    'highest_streak': 9,
#    'games': 1946,
#    'wins': 1067,
#    'losses': 879,
#    'drops': 5,
#    'last_match_time': 1682253934},
#   {'profile_id': 230475,
#    'rank': 51,
#    'rating': 2414,
#    'steam_id': '76561198068729026',
#    'icon': None,
#    'name': 'El_Matador',
#    'clan': None,
#    'country': 'DE',
#    'previous_rating': 2397,
#    'highest_rating': 2445,
#    'streak': 1,
#    'lowest_streak': -11,
#    'highest_streak': 12,
#    'games': 6243,
#    'wins': 3204,
#    'losses': 3039,
#    'drops': 21,
#    'last_match_time': 1682264917},
#   {'profile_id': 2660491,
#    'rank': 52,
#    'rating': 2413,
#    'steam_id': '76561199054206296',
#    'icon': None,
#    'name': 'Thành Cổ Quảng Trị &lt;Hope&gt;',
#    'clan': 'LuLe',
#    'country': 'VN',
#    'previous_rating': 2421,
#    'highest_rating': 2444,
#    'streak': -2,
#    'lowest_streak': -10,
#    'highest_streak': 12,
#    'games': 2862,
#    'wins': 1444,
#    'losses': 1418,
#    'drops': 31,
#    'last_match_time': 1682251180},
#   {'profile_id': 2858362,
#    'rank': 53,
#    'rating': 2412,
#    'steam_id': '76561198400058723',
#    'icon': None,
#    'name': 'GL.JorDan_AoE',
#    'clan': None,
#    'country': 'DE',
#    'previous_rating': 2403,
#    'highest_rating': 2760,
#    'streak': 2,
#    'lowest_streak': -10,
#    'highest_streak': 27,
#    'games': 1784,
#    'wins': 1038,
#    'losses': 746,
#    'drops': 13,
#    'last_match_time': 1682081563},
#   {'profile_id': 288714,
#    'rank': 54,
#    'rating': 2410,
#    'steam_id': '76561198282860959',
#    'icon': None,
#    'name': 'Mihai06',
#    'clan': 'ROTLD',
#    'country': 'RO',
#    'previous_rating': 2427,
#    'highest_rating': 2570,
#    'streak': -1,
#    'lowest_streak': -9,
#    'highest_streak': 12,
#    'games': 3930,
#    'wins': 2099,
#    'losses': 1831,
#    'drops': 48,
#    'last_match_time': 1682264917},
#   {'profile_id': 1224481,
#    'rank': 55,
#    'rating': 2404,
#    'steam_id': '76561198368620113',
#    'icon': None,
#    'name': 'IW.Kasva',
#    'clan': 'HymTr',
#    'country': 'TR',
#    'previous_rating': 2421,
#    'highest_rating': 2502,
#    'streak': -1,
#    'lowest_streak': -9,
#    'highest_streak': 13,
#    'games': 5220,
#    'wins': 2873,
#    'losses': 2347,
#    'drops': 39,
#    'last_match_time': 1682258251},
#   {'profile_id': 2886954,
#    'rank': 56,
#    'rating': 2400,
#    'steam_id': '76561198317794461',
#    'icon': None,
#    'name': '^^anomeL',
#    'clan': None,
#    'country': 'RU',
#    'previous_rating': 2379,
#    'highest_rating': 2400,
#    'streak': 5,
#    'lowest_streak': -3,
#    'highest_streak': 20,
#    'games': 270,
#    'wins': 197,
#    'losses': 73,
#    'drops': 2,
#    'last_match_time': 1681811006},
#   {'profile_id': 1531083,
#    'rank': 57,
#    'rating': 2391,
#    'steam_id': '76561198056609593',
#    'icon': None,
#    'name': 'mYi.FreakinAndy',
#    'clan': None,
#    'country': 'AT',
#    'previous_rating': 2404,
#    'highest_rating': 2672,
#    'streak': -3,
#    'lowest_streak': -9,
#    'highest_streak': 13,
#    'games': 1167,
#    'wins': 698,
#    'losses': 469,
#    'drops': 7,
#    'last_match_time': 1682206728},
#   {'profile_id': 3552644,
#    'rank': 58,
#    'rating': 2386,
#    'steam_id': '76561199096859133',
#    'icon': None,
#    'name': 'TimeToEnjoy',
#    'clan': None,
#    'country': 'CA',
#    'previous_rating': 2369,
#    'highest_rating': 2471,
#    'streak': 1,
#    'lowest_streak': -5,
#    'highest_streak': 20,
#    'games': 405,
#    'wins': 279,
#    'losses': 126,
#    'drops': 0,
#    'last_match_time': 1681573221},
#   {'profile_id': 211351,
#    'rank': 59,
#    'rating': 2382,
#    'steam_id': '76561198262978341',
#    'icon': None,
#    'name': '抖音帝国时代灵魂导师',
#    'clan': 'WWP',
#    'country': 'CN',
#    'previous_rating': 2405,
#    'highest_rating': 2410,
#    'streak': -1,
#    'lowest_streak': -8,
#    'highest_streak': 9,
#    'games': 1404,
#    'wins': 764,
#    'losses': 640,
#    'drops': 13,
#    'last_match_time': 1681220862},
#   {'profile_id': 576919,
#    'rank': 60,
#    'rating': 2381,
#    'steam_id': '76561198082024695',
#    'icon': None,
#    'name': 'Babaorum',
#    'clan': None,
#    'country': 'FR',
#    'previous_rating': 2396,
#    'highest_rating': 2493,
#    'streak': -1,
#    'lowest_streak': -9,
#    'highest_streak': 15,
#    'games': 3156,
#    'wins': 1808,
#    'losses': 1348,
#    'drops': 16,
#    'last_match_time': 1682263802},
#   {'profile_id': 10336997,
#    'rank': 61,
#    'rating': 2380,
#    'steam_id': '76561199326626083',
#    'icon': None,
#    'name': 'Kalong亲卫队队长',
#    'clan': None,
#    'country': 'HK',
#    'previous_rating': 2364,
#    'highest_rating': 2419,
#    'streak': 4,
#    'lowest_streak': -5,
#    'highest_streak': 34,
#    'games': 281,
#    'wins': 189,
#    'losses': 92,
#    'drops': 4,
#    'last_match_time': 1682255585},
#   {'profile_id': 2654577,
#    'rank': 62,
#    'rating': 2379,
#    'steam_id': '76561198826220092',
#    'icon': None,
#    'name': 'Ozone',
#    'clan': None,
#    'country': 'CO',
#    'previous_rating': 2400,
#    'highest_rating': 2400,
#    'streak': -1,
#    'lowest_streak': -10,
#    'highest_streak': 12,
#    'games': 10624,
#    'wins': 5414,
#    'losses': 5210,
#    'drops': 78,
#    'last_match_time': 1681929758},
#   {'profile_id': 217905,
#    'rank': 63,
#    'rating': 2375,
#    'steam_id': '76561198116269715',
#    'icon': None,
#    'name': 'chart',
#    'clan': 'ALL',
#    'country': 'JP',
#    'previous_rating': 2359,
#    'highest_rating': 2424,
#    'streak': 2,
#    'lowest_streak': -7,
#    'highest_streak': 11,
#    'games': 1144,
#    'wins': 662,
#    'losses': 482,
#    'drops': 9,
#    'last_match_time': 1682262123},
#   {'profile_id': 716717,
#    'rank': 64,
#    'rating': 2369,
#    'steam_id': '76561198367310298',
#    'icon': None,
#    'name': '抖音帝国时代2狗哥',
#    'clan': 'AreS',
#    'country': 'CN',
#    'previous_rating': 2352,
#    'highest_rating': 2479,
#    'streak': 2,
#    'lowest_streak': -9,
#    'highest_streak': 13,
#    'games': 1826,
#    'wins': 1073,
#    'losses': 753,
#    'drops': 24,
#    'last_match_time': 1682182110},
#   {'profile_id': 2754047,
#    'rank': 65,
#    'rating': 2367,
#    'steam_id': '76561199062001759',
#    'icon': None,
#    'name': 'TennesseeWhiskey',
#    'clan': None,
#    'country': 'PL',
#    'previous_rating': 2342,
#    'highest_rating': 2417,
#    'streak': 2,
#    'lowest_streak': -8,
#    'highest_streak': 9,
#    'games': 1100,
#    'wins': 597,
#    'losses': 503,
#    'drops': 23,
#    'last_match_time': 1682257827},
#   {'profile_id': 2621722,
#    'rank': 66,
#    'rating': 2364,
#    'steam_id': '76561198046946243',
#    'icon': None,
#    'name': 'Twigg',
#    'clan': 'Biry',
#    'country': 'AR',
#    'previous_rating': 2381,
#    'highest_rating': 2478,
#    'streak': -9,
#    'lowest_streak': -9,
#    'highest_streak': 18,
#    'games': 1650,
#    'wins': 901,
#    'losses': 749,
#    'drops': 28,
#    'last_match_time': 1682179556},
#   {'profile_id': 1252385,
#    'rank': 67,
#    'rating': 2360,
#    'steam_id': '76561199014766072',
#    'icon': None,
#    'name': 'Carpincho',
#    'clan': None,
#    'country': 'AR',
#    'previous_rating': 2405,
#    'highest_rating': 2405,
#    'streak': 11,
#    'lowest_streak': -7,
#    'highest_streak': 11,
#    'games': 720,
#    'wins': 408,
#    'losses': 312,
#    'drops': 9,
#    'last_match_time': 1680149081},
#   {'profile_id': 2135484,
#    'rank': 68,
#    'rating': 2358,
#    'steam_id': '76561199035860327',
#    'icon': None,
#    'name': 'bruh',
#    'clan': None,
#    'country': 'BR',
#    'previous_rating': 2377,
#    'highest_rating': 2468,
#    'streak': -1,
#    'lowest_streak': -10,
#    'highest_streak': 16,
#    'games': 3155,
#    'wins': 1706,
#    'losses': 1449,
#    'drops': 55,
#    'last_match_time': 1682132952},
#   {'profile_id': 6268226,
#    'rank': 69,
#    'rating': 2353,
#    'steam_id': '76561199197809267',
#    'icon': None,
#    'name': '抖音帝国时代痛大师',
#    'clan': 'WE4SC',
#    'country': 'CN',
#    'previous_rating': 2334,
#    'highest_rating': 2353,
#    'streak': 3,
#    'lowest_streak': -9,
#    'highest_streak': 29,
#    'games': 1355,
#    'wins': 734,
#    'losses': 621,
#    'drops': 13,
#    'last_match_time': 1681993560},
#   {'profile_id': 197751,
#    'rank': 70,
#    'rating': 2351,
#    'steam_id': '76561197964180873',
#    'icon': None,
#    'name': 'GL.Nili',
#    'clan': 'Liiit',
#    'country': 'DE',
#    'previous_rating': 2369,
#    'highest_rating': 2472,
#    'streak': -2,
#    'lowest_streak': -11,
#    'highest_streak': 12,
#    'games': 2288,
#    'wins': 1225,
#    'losses': 1063,
#    'drops': 8,
#    'last_match_time': 1681765435},
#   {'profile_id': 11906939,
#    'rank': 71,
#    'rating': 2350,
#    'steam_id': '76561199439830461',
#    'icon': None,
#    'name': 'Gm',
#    'clan': None,
#    'country': None,
#    'previous_rating': 2366,
#    'highest_rating': 2389,
#    'streak': -1,
#    'lowest_streak': -3,
#    'highest_streak': 20,
#    'games': 166,
#    'wins': 124,
#    'losses': 42,
#    'drops': 1,
#    'last_match_time': 1682262123},
#   {'profile_id': 4785288,
#    'rank': 72,
#    'rating': 2348,
#    'steam_id': '76561199129096097',
#    'icon': None,
#    'name': 'Combi | 7Swords',
#    'clan': None,
#    'country': 'MX',
#    'previous_rating': 2354,
#    'highest_rating': 2452,
#    'streak': -4,
#    'lowest_streak': -7,
#    'highest_streak': 27,
#    'games': 987,
#    'wins': 527,
#    'losses': 460,
#    'drops': 12,
#    'last_match_time': 1682134566},
#   {'profile_id': 226575,
#    'rank': 73,
#    'rating': 2347,
#    'steam_id': '76561198313422112',
#    'icon': None,
#    'name': '_EMA_003',
#    'clan': 'WWP',
#    'country': 'CN',
#    'previous_rating': 2363,
#    'highest_rating': 2480,
#    'streak': -1,
#    'lowest_streak': -8,
#    'highest_streak': 10,
#    'games': 2077,
#    'wins': 1142,
#    'losses': 935,
#    'drops': 16,
#    'last_match_time': 1682255585},
#   {'profile_id': 3101322,
#    'rank': 74,
#    'rating': 2343,
#    'steam_id': '76561198151895411',
#    'icon': None,
#    'name': 'HR Whitecourt',
#    'clan': 'QNA',
#    'country': 'CL',
#    'previous_rating': 2387,
#    'highest_rating': 2393,
#    'streak': 2,
#    'lowest_streak': -6,
#    'highest_streak': 14,
#    'games': 1222,
#    'wins': 685,
#    'losses': 537,
#    'drops': 3,
#    'last_match_time': 1679878067},
#   {'profile_id': 4632681,
#    'rank': 75,
#    'rating': 2340,
#    'steam_id': '76561198439558568',
#    'icon': None,
#    'name': 'Overtaken',
#    'clan': None,
#    'country': 'EE',
#    'previous_rating': 2362,
#    'highest_rating': 2517,
#    'streak': -1,
#    'lowest_streak': -9,
#    'highest_streak': 17,
#    'games': 2406,
#    'wins': 1302,
#    'losses': 1104,
#    'drops': 17,
#    'last_match_time': 1682261474},
#   {'profile_id': 4012008,
#    'rank': 76,
#    'rating': 2333,
#    'steam_id': '76561198294644972',
#    'icon': None,
#    'name': 'chaos_2_win',
#    'clan': None,
#    'country': 'DE',
#    'previous_rating': 2323,
#    'highest_rating': 2335,
#    'streak': 2,
#    'lowest_streak': -8,
#    'highest_streak': 18,
#    'games': 1829,
#    'wins': 956,
#    'losses': 873,
#    'drops': 8,
#    'last_match_time': 1681858387},
#   {'profile_id': 11962856,
#    'rank': 77,
#    'rating': 2325,
#    'steam_id': '76561198237386056',
#    'icon': None,
#    'name': 'Ozone v2.0',
#    'clan': None,
#    'country': 'CO',
#    'previous_rating': 2313,
#    'highest_rating': 2353,
#    'streak': 4,
#    'lowest_streak': -6,
#    'highest_streak': 22,
#    'games': 344,
#    'wins': 212,
#    'losses': 132,
#    'drops': 0,
#    'last_match_time': 1682193127},
#   {'profile_id': 3446882,
#    'rank': 78,
#    'rating': 2315,
#    'steam_id': '76561199091668803',
#    'icon': None,
#    'name': 'HOWL.Kozmonot',
#    'clan': 'HymTr',
#    'country': 'TR',
#    'previous_rating': 2302,
#    'highest_rating': 2382,
#    'streak': 1,
#    'lowest_streak': -10,
#    'highest_streak': 18,
#    'games': 1213,
#    'wins': 634,
#    'losses': 579,
#    'drops': 13,
#    'last_match_time': 1682207686},
#   {'profile_id': 986504,
#    'rank': 79,
#    'rating': 2309,
#    'steam_id': '76561198169764954',
#    'icon': None,
#    'name': 'twitch.tv/st4rk_',
#    'clan': None,
#    'country': 'BR',
#    'previous_rating': 2294,
#    'highest_rating': 2309,
#    'streak': 5,
#    'lowest_streak': -8,
#    'highest_streak': 12,
#    'games': 1462,
#    'wins': 877,
#    'losses': 585,
#    'drops': 11,
#    'last_match_time': 1681852543},
#   {'profile_id': 213305,
#    'rank': 80,
#    'rating': 2308,
#    'steam_id': '76561198152110843',
#    'icon': None,
#    'name': 'The_Damn_Bugum',
#    'clan': None,
#    'country': 'BE',
#    'previous_rating': 2319,
#    'highest_rating': 2485,
#    'streak': -1,
#    'lowest_streak': -9,
#    'highest_streak': 19,
#    'games': 3786,
#    'wins': 2240,
#    'losses': 1546,
#    'drops': 12,
#    'last_match_time': 1682176502},
#   {'profile_id': 458029,
#    'rank': 81,
#    'rating': 2307,
#    'steam_id': '76561197981262667',
#    'icon': None,
#    'name': 'CL.Darknoob',
#    'clan': 'C1own',
#    'country': 'NL',
#    'previous_rating': 2293,
#    'highest_rating': 2385,
#    'streak': 3,
#    'lowest_streak': -10,
#    'highest_streak': 11,
#    'games': 5404,
#    'wins': 2900,
#    'losses': 2504,
#    'drops': 34,
#    'last_match_time': 1682019562},
#   {'profile_id': 292318,
#    'rank': 82,
#    'rating': 2307,
#    'steam_id': '76561198086560184',
#    'icon': None,
#    'name': 'Rayzor',
#    'clan': 'AUNZ',
#    'country': 'AU',
#    'previous_rating': 2296,
#    'highest_rating': 2356,
#    'streak': 1,
#    'lowest_streak': -7,
#    'highest_streak': 8,
#    'games': 1142,
#    'wins': 639,
#    'losses': 503,
#    'drops': 4,
#    'last_match_time': 1681896828},
#   {'profile_id': 250103,
#    'rank': 83,
#    'rating': 2305,
#    'steam_id': '76561198061054857',
#    'icon': None,
#    'name': '_Hallis',
#    'clan': None,
#    'country': 'GB',
#    'previous_rating': 2330,
#    'highest_rating': 2442,
#    'streak': -1,
#    'lowest_streak': -8,
#    'highest_streak': 13,
#    'games': 3277,
#    'wins': 1727,
#    'losses': 1550,
#    'drops': 29,
#    'last_match_time': 1681952348},
#   {'profile_id': 3335279,
#    'rank': 84,
#    'rating': 2304,
#    'steam_id': '76561199086871914',
#    'icon': None,
#    'name': 'Tartopum',
#    'clan': None,
#    'country': 'FR',
#    'previous_rating': 2346,
#    'highest_rating': 2426,
#    'streak': 1,
#    'lowest_streak': -5,
#    'highest_streak': 30,
#    'games': 371,
#    'wins': 241,
#    'losses': 130,
#    'drops': 3,
#    'last_match_time': 1680884891},
#   {'profile_id': 1793493,
#    'rank': 85,
#    'rating': 2304,
#    'steam_id': '76561198289483955',
#    'icon': None,
#    'name': 'Shades',
#    'clan': 'RoR',
#    'country': 'IT',
#    'previous_rating': 2285,
#    'highest_rating': 2304,
#    'streak': 4,
#    'lowest_streak': -9,
#    'highest_streak': 14,
#    'games': 1824,
#    'wins': 952,
#    'losses': 872,
#    'drops': 18,
#    'last_match_time': 1682181283},
#   {'profile_id': 3176045,
#    'rank': 86,
#    'rating': 2302,
#    'steam_id': '76561199054087176',
#    'icon': None,
#    'name': 'XEVER | Prisma09',
#    'clan': 'XEVER',
#    'country': 'AR',
#    'previous_rating': 2285,
#    'highest_rating': 2302,
#    'streak': 1,
#    'lowest_streak': -12,
#    'highest_streak': 10,
#    'games': 3790,
#    'wins': 1943,
#    'losses': 1847,
#    'drops': 22,
#    'last_match_time': 1681314895},
#   {'profile_id': 9695965,
#    'rank': 87,
#    'rating': 2296,
#    'steam_id': '76561199248045654',
#    'icon': None,
#    'name': '猪头',
#    'clan': None,
#    'country': 'CN',
#    'previous_rating': 2337,
#    'highest_rating': 2456,
#    'streak': 5,
#    'lowest_streak': -8,
#    'highest_streak': 30,
#    'games': 344,
#    'wins': 245,
#    'losses': 99,
#    'drops': 2,
#    'last_match_time': 1681047809},
#   {'profile_id': 77944,
#    'rank': 88,
#    'rating': 2296,
#    'steam_id': '76561198057191173',
#    'icon': None,
#    'name': '_Tomate',
#    'clan': None,
#    'country': 'ES',
#    'previous_rating': 2318,
#    'highest_rating': 2339,
#    'streak': -2,
#    'lowest_streak': -11,
#    'highest_streak': 17,
#    'games': 3170,
#    'wins': 1611,
#    'losses': 1559,
#    'drops': 13,
#    'last_match_time': 1682255352},
#   {'profile_id': 945852,
#    'rank': 89,
#    'rating': 2291,
#    'steam_id': '76561198075555979',
#    'icon': None,
#    'name': 'Lucky Rox',
#    'clan': 'Biry',
#    'country': 'AR',
#    'previous_rating': 2307,
#    'highest_rating': 2405,
#    'streak': -1,
#    'lowest_streak': -8,
#    'highest_streak': 16,
#    'games': 1200,
#    'wins': 676,
#    'losses': 524,
#    'drops': 8,
#    'last_match_time': 1682187927},
#   {'profile_id': 222528,
#    'rank': 90,
#    'rating': 2290,
#    'steam_id': '76561198034782642',
#    'icon': None,
#    'name': 'repard',
#    'clan': None,
#    'country': 'RU',
#    'previous_rating': 2308,
#    'highest_rating': 2462,
#    'streak': -1,
#    'lowest_streak': -10,
#    'highest_streak': 16,
#    'games': 1814,
#    'wins': 955,
#    'losses': 859,
#    'drops': 16,
#    'last_match_time': 1682178087},
#   {'profile_id': 372704,
#    'rank': 91,
#    'rating': 2289,
#    'steam_id': '76561198261008535',
#    'icon': None,
#    'name': 'ValihrAnt',
#    'clan': None,
#    'country': 'LV',
#    'previous_rating': 2273,
#    'highest_rating': 2330,
#    'streak': 2,
#    'lowest_streak': -9,
#    'highest_streak': 8,
#    'games': 1914,
#    'wins': 990,
#    'losses': 924,
#    'drops': 21,
#    'last_match_time': 1682245311},
#   {'profile_id': 245811,
#    'rank': 92,
#    'rating': 2286,
#    'steam_id': '76561198027802048',
#    'icon': None,
#    'name': 'Target331',
#    'clan': None,
#    'country': 'DE',
#    'previous_rating': 2306,
#    'highest_rating': 2320,
#    'streak': -2,
#    'lowest_streak': -8,
#    'highest_streak': 11,
#    'games': 903,
#    'wins': 505,
#    'losses': 398,
#    'drops': 5,
#    'last_match_time': 1682238042},
#   {'profile_id': 197930,
#    'rank': 93,
#    'rating': 2280,
#    'steam_id': '76561198088178833',
#    'icon': None,
#    'name': 'T90Official',
#    'clan': None,
#    'country': 'US',
#    'previous_rating': 2298,
#    'highest_rating': 2370,
#    'streak': -2,
#    'lowest_streak': -9,
#    'highest_streak': 12,
#    'games': 2394,
#    'wins': 1295,
#    'losses': 1099,
#    'drops': 11,
#    'last_match_time': 1681941218},
#   {'profile_id': 2821779,
#    'rank': 94,
#    'rating': 2279,
#    'steam_id': '76561199065337729',
#    'icon': None,
#    'name': 'DS_Levi',
#    'clan': 'Biry',
#    'country': 'AR',
#    'previous_rating': 2292,
#    'highest_rating': 2328,
#    'streak': -1,
#    'lowest_streak': -8,
#    'highest_streak': 23,
#    'games': 2321,
#    'wins': 1213,
#    'losses': 1108,
#    'drops': 7,
#    'last_match_time': 1682219662},
#   {'profile_id': 2559615,
#    'rank': 95,
#    'rating': 2279,
#    'steam_id': '76561199054259190',
#    'icon': None,
#    'name': 'FreakinAndy',
#    'clan': None,
#    'country': 'AT',
#    'previous_rating': 2320,
#    'highest_rating': 2565,
#    'streak': 2,
#    'lowest_streak': -9,
#    'highest_streak': 15,
#    'games': 1420,
#    'wins': 781,
#    'losses': 639,
#    'drops': 7,
#    'last_match_time': 1679951643},
#   {'profile_id': 212294,
#    'rank': 96,
#    'rating': 2278,
#    'steam_id': '76561198169336974',
#    'icon': None,
#    'name': 'CL.D3rp',
#    'clan': 'C1own',
#    'country': 'NL',
#    'previous_rating': 2289,
#    'highest_rating': 2355,
#    'streak': -3,
#    'lowest_streak': -8,
#    'highest_streak': 9,
#    'games': 2778,
#    'wins': 1461,
#    'losses': 1317,
#    'drops': 24,
#    'last_match_time': 1682255715},
#   {'profile_id': 247224,
#    'rank': 97,
#    'rating': 2278,
#    'steam_id': '76561198171294807',
#    'icon': None,
#    'name': 'Survivalist',
#    'clan': None,
#    'country': 'CA',
#    'previous_rating': 2288,
#    'highest_rating': 2288,
#    'streak': -1,
#    'lowest_streak': -10,
#    'highest_streak': 13,
#    'games': 7184,
#    'wins': 3671,
#    'losses': 3513,
#    'drops': 22,
#    'last_match_time': 1682238405},
#   {'profile_id': 243287,
#    'rank': 98,
#    'rating': 2278,
#    'steam_id': '76561198297171662',
#    'icon': None,
#    'name': '勇敢熊熊',
#    'clan': 'WWP',
#    'country': 'CN',
#    'previous_rating': 2276,
#    'highest_rating': 2379,
#    'streak': -1,
#    'lowest_streak': -8,
#    'highest_streak': 10,
#    'games': 3049,
#    'wins': 1590,
#    'losses': 1459,
#    'drops': 36,
#    'last_match_time': 1682008462},
#   {'profile_id': 2462063,
#    'rank': 99,
#    'rating': 2277,
#    'steam_id': '76561199050788934',
#    'icon': None,
#    'name': 'Shades',
#    'clan': None,
#    'country': 'IT',
#    'previous_rating': 2288,
#    'highest_rating': 2297,
#    'streak': -2,
#    'lowest_streak': -9,
#    'highest_streak': 13,
#    'games': 800,
#    'wins': 422,
#    'losses': 378,
#    'drops': 7,
#    'last_match_time': 1681133041},
#   {'profile_id': 245117,
#    'rank': 100,
#    'rating': 2276,
#    'steam_id': '76561198078010430',
#    'icon': None,
#    'name': 'Cl3m3nT',
#    'clan': 'FrCo',
#    'country': 'FR',
#    'previous_rating': 2266,
#    'highest_rating': 2316,
#    'streak': 2,
#    'lowest_streak': -7,
#    'highest_streak': 10,
#    'games': 1018,
#    'wins': 580,
#    'losses': 438,
#    'drops': 7,
#    'last_match_time': 1682256247}]}

# %%
def make_dataframe(data: dict) -> pd.DataFrame:
    # Creating a DataFrame from the dictionary
    df = pd.DataFrame(data['leaderboard'])
    
    # Adding a column with the current date and time
    df['Timestamp'] = pd.Timestamp.now()
    
    return df

# %%
def write_csv(date, dataframe):
    '''Write DataFrame to CSV file with today's date in the filename'''
    
    filename = f"data_{date}_1.csv"
    dataframe.to_csv(f'data/{filename}', index=False, header=True)

# %%
def main():
    url = 'https://aoe2.net/api/leaderboard'
    
    data = get_data_by_api(url)
    
    df = make_dataframe(data)
    
    # Get today's date
    today = datetime.today().strftime('%Y%m%d')
    
    write_csv(today, df)
    
main()
